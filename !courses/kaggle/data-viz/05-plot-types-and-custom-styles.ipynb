# %% [markdown]
# # [Plot Types and Custom Styles](https://www.kaggle.com/code/alexisbcook/choosing-plot-types-and-custom-styles)
#
#
# ## Plot Types
# We've now learnt the following types of charts, which have been ordered below based on what type of relationship you want to visualise:
#
# ![plot types](https://imgur.com/LPWH19I.png)
#
# ## Custom Styles

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
import random as rd

# Import prepped data
lap_times  = pd.read_csv('./intermediate/lap_times_prepped.csv')
pit_stops  = pd.read_csv('./intermediate/pit_stops_prepped.csv')
qualifying = pd.read_csv('./intermediate/qualifying_prepped.csv')
results    = pd.read_csv('./intermediate/results_prepped.csv')
# Out:
# /var/folders/0p/fnlsdkq159s9phmzxxmms5pc0000gn/T/ipykernel_46887/1033431768.py:10: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   lap_times  = pd.read_csv('./intermediate/lap_times_prepped.csv')

# %% [markdown]
# Set the style of the charts you produce with `sns.set_style()`. Let's see the effects of this on the line chart we produced in lesson 1.

# %%
# Plotting by seconds for ease of interpretation (vs. milliseconds)
lap_times['seconds'] = lap_times['milliseconds'] / 1000

lap_times_vettel_2016 = lap_times.loc[
    (lap_times['driverRef'] == 'vettel') & 
    (lap_times['year'] == 2016) & 
    (lap_times['round'] >= 2) &
    (lap_times['round'] <= 12)
]

# %%
# Plot - darkgrid theme
sns.set_style('darkgrid')
plt.figure(figsize = (14, 6))
plt.title("Sebastian Vettel Lap Times - Subset of 2016 Races")

sns.lineplot(data = lap_times_vettel_2016, x = 'lap', y = 'seconds', hue = 'name')

plt.xlabel('Lap Number')
plt.ylabel('Time (Seconds)')
# Out:
# Text(0, 0.5, 'Time (Seconds)')

# %%
# Plot - whitegrid theme
sns.set_style('whitegrid')
plt.figure(figsize = (14, 6))
plt.title("Sebastian Vettel Lap Times - Subset of 2016 Races")

sns.lineplot(data = lap_times_vettel_2016, x = 'lap', y = 'seconds', hue = 'name')

plt.xlabel('Lap Number')
plt.ylabel('Time (Seconds)')
# Out:
# Text(0, 0.5, 'Time (Seconds)')

# %%
# Plot - dark theme
sns.set_style('dark')
plt.figure(figsize = (14, 6))
plt.title("Sebastian Vettel Lap Times - Subset of 2016 Races")

sns.lineplot(data = lap_times_vettel_2016, x = 'lap', y = 'seconds', hue = 'name')

plt.xlabel('Lap Number')
plt.ylabel('Time (Seconds)')
# Out:
# Text(0, 0.5, 'Time (Seconds)')

# %%
# Plot - white theme
sns.set_style('white')
plt.figure(figsize = (14, 6))
plt.title("Sebastian Vettel Lap Times - Subset of 2016 Races")

sns.lineplot(data = lap_times_vettel_2016, x = 'lap', y = 'seconds', hue = 'name')

plt.xlabel('Lap Number')
plt.ylabel('Time (Seconds)')
# Out:
# Text(0, 0.5, 'Time (Seconds)')

# %%
# Plot - ticks theme
sns.set_style('ticks')
plt.figure(figsize = (14, 6))
plt.title("Sebastian Vettel Lap Times - Subset of 2016 Races")

sns.lineplot(data = lap_times_vettel_2016, x = 'lap', y = 'seconds', hue = 'name')

plt.xlabel('Lap Number')
plt.ylabel('Time (Seconds)')
# Out:
# Text(0, 0.5, 'Time (Seconds)')
